# %% [markdown]
# ## Python Blackjack
# For this project you will make a Blackjack game using Python. Click <a href="http://www.hitorstand.net/strategy.php">here</a> to familiarize yourself with the the rules of the game. You won't be implementing every rule "down to the letter" with the game, but we will doing a simpler version of the game. This assignment will be given to further test your knowledge on object-oriented programming concepts.
#
# ### Rules:
#
# `1. ` The game will have two players: the Dealer and the Player. The game will start off with a deck of 52 cards. The 52 cards will consist of 4 different suits: Clubs, Diamonds, Hearts and Spades. For each suit, there will be cards numbered 1 through 13. <br>
# **Note: No wildcards will be used in the program**
#
# `2. ` When the game begins, the dealer will shuffle the deck of cards, making them randomized. After the dealer shuffles, it will deal the player 2 cards and will deal itself 2 cards from. The Player should be able to see both of their own cards, but should only be able to see one of the Dealer's cards.
#
# `3. ` The objective of the game is for the Player to count their cards after they're dealt. If they're not satisfied with the number, they have the ability to 'Hit'. A hit allows the dealer to deal the Player one additional card. The Player can hit as many times as they'd like as long as they don't 'Bust'. A bust is when the Player is dealt cards that total more than 21.
#
# `4. ` If the dealer deals the Player cards equal to 21 on the **first** deal, the Player wins. This is referred to as Blackjack. Blackjack is **NOT** the same as getting cards that equal up to 21 after the first deal. Blackjack can only be attained on the first deal.
#
# `5. ` The Player will never see the Dealer's hand until the Player chooses to 'stand'. A Stand is when the player tells the dealer to not deal it anymore cards. Once the player chooses to Stand, the Player and the Dealer will compare their hands. Whoever has the higher number wins. Keep in mind that the Dealer can also bust.

# %%
import random
import time
from cards_module import cards as c


class Player:
    deal_counter = 1

    def __init__(self):
        self.deck1 = []
        self.points1 = 0

    def game_start(self):
        print("The Game has started, Cards are being dealt...")
        time.sleep(2)
        self.deck1 = random.sample(c, k=2)
        for suit, num in self.deck1:
            self.points1 += num
        print(f"Cards have been Dealt, you currently have {self.deck1}")
        time.sleep(2)
        if self.points1 == 21:
            print("Blackjack! You have won!")
            end()
        if self.points1 > 21:
            print("Bust! you have over 21 points, you lose!")
            end()

    def check_cards(self):
        print(self.deck1)
        time.sleep(2)

    def hit(self):
        card = random.sample(c, k=1)
        self.deck1.append(card)
        for suit, num in card:
            self.points1 += num
        if self.points1 > 21:
            print("Bust! you have over 21 points, you lose!")
            end()

    def __str__(self):
        for suit, num in self.deck1:
            self.points1 += num
        return f'You have {self.points1} points'


class Dealer(Player):

    def __init__(self):
        self.deck = ""
        self.points = 0

    def check_deal_card(self):
        print(f"{self.deck[1]} is one of the Dealers Cards")
        time.sleep(2)

    def game_start(self):
        self.deck = random.sample(c, k=2)
        for suit, num in self.deck:
            self.points += num
        if self.points >= 21:
            print("Bust! The Dealer has lost!")
            time.sleep(2)
            end()

    def hit(self):
        card = random.sample(c, k=1)
        self.deck.append(card)
        for suit, num in card:
            self.points += num
        if self.points > 21:
            print("Bust! The Dealer has over 21 points, It loses!")
            end()

    def stand(self):
        super().__init__()
        if self.points1 > self.points:
            print(
                f"You've won! You have {self.points1} and the dealer has {self.points}")
            time.sleep(2)
            end()
        if self.points1 < self.points:
            print(
                f"You've lost, You have {self.points1} and the dealer has {self.points}")
            time.sleep(2)
            end()


def blackjack():
    player = Player()
    dealer = Dealer()
    player.game_start()
    dealer.game_start()
    while True:
        print('''
        Your Options to Continue are:
        ------------------------------------------
        1) Hit
        2) Stand
        3) Check your Cards
        4) See One of the Dealers Cards
        ------------------------------------------
        ''')
        choices = input("Which one would you like to do?: ")
        while choices not in {'1', '2', '3', '4'}:
            choices = input('Invalid Option. Please Choose a Valid Option: ')
        if choices == '1':
            player.hit()
            dealer.hit()
        if choices == '2':
            dealer.stand()
        if choices == '3':
            player.check_cards()
        if choices == '4':
            dealer.check_deal_card()


def end():
    while True:
        print('''
        Thank you for playing! would you like to try again?
        ''')
        choice1 = input("Yes(1) or No(2)?: ")
        while choice1 not in {'1', "2"}:
            choice1 = input('Invalid Option. Please Choose a Valid Option: ')
        if choice1 == '1':
            blackjack()
        elif choice1 == '2':
            break


blackjack()
# Out:
# The Game has started, Cards are being dealt...
# Cards have been Dealt, you currently have [('Clubs', 2), ('Hearts', 1)]
#
#         Your Options to Continue are:
#         ------------------------------------------
#         1) Hit
#         2) Stand
#         3) Check your Cards
#         4) See One of the Dealers Cards
#         ------------------------------------------
#
# Which one would you like to do?: 1
#
#         Your Options to Continue are:
#         ------------------------------------------
#         1) Hit
#         2) Stand
#         3) Check your Cards
#         4) See One of the Dealers Cards
#         ------------------------------------------
#
# Which one would you like to do?: 1
# Bust! The Dealer has over 21 points, It loses!
#
#         Thank you for playing! would you like to try again?
#
# Yes(1) or No(2)?: 1
# The Game has started, Cards are being dealt...
# Cards have been Dealt, you currently have [('Clubs', 12), ('Spades', 13)]
# ...
